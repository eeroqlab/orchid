# %%
from pathlib import Path
from orchid import DashPlotter

# %%
data_dir = Path.cwd()

# %%
browser = DashPlotter.browse(data_dir / Path("data"))
# Out:
# Orchid experiment browser at http://localhost:8053

# %%
browser.stop()
# Out:
# Orchid browse server stopped (port 8053).
